# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# Configurar opciones para Chrome
chrome_options = Options()
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")

# Conectar con Selenium en Docker
driver = webdriver.Remote(
    command_executor="http://localhost:4444/wd/hub",
    options=chrome_options
)

# Navegar a Google
driver.get("https://www.google.com")

# Tomar una captura de pantalla
screenshot_path = "/tmp/captura.png"
driver.save_screenshot(screenshot_path)
print(f"Captura de pantalla guardada en {screenshot_path}")

# Cerrar el navegador
driver.quit()
# Out:
# Captura de pantalla guardada en /tmp/captura.png

# %%
from IPython.display import display
from PIL import Image

# Mostrar la captura de pantalla en el notebook
image = Image.open(screenshot_path)
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=937x895>
